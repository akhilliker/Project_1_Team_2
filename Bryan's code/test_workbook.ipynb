# %%
#import dependencies
import pandas as pd
import requests
import json
import gmaps
import time
from config import api_key
from config_new import gkey

# %%
url = "https://api.brewerydb.com/v2/locations/?key=" + api_key + "&countryIsoCode=US"
response=requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "currentPage": 1,
#     "data": [
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "KHNY4IGTS6",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2012-01-03 02:41:47",
#                 "description": "Boulder Beer Company, Colorado's First Craft Brewery, was founded in 1979 when two University of Colorado professors applied for and received the 43rd brewing license in the United States.  The brewery has a full service pub that's open daily for lunch and dinner, with a spacious outdoor beer garden offering amazing view of Boulder's Flatirons. Brewery Tours daily at 2pm, and Sat at 4pm.",
#                 "established": "1979",
#                 "id": "stdQLg",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/stdQLg/upload_fa6I3w-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/stdQLg/upload_fa6I3w-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/stdQLg/upload_fa6I3w-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/stdQLg/upload_fa6I3w-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/stdQLg/upload_fa6I3w-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "Y",
#                 "name": "Boulder Beer Company",
#                 "nameShortDisplay": "Boulder",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-08 19:40:43",
#                 "website": "http://www.boulderbeer.com/"
#             },
#             "breweryId": "stdQLg",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2018-06-20 15:14:08",
#             "id": "udRaBO",
#             "inPlanning": "N",
#             "isClosed": "Y",
#             "isPrimary": "N",
#             "latitude": 40.0168706,
#             "locality": "Boulder",
#             "locationType": "brewpub",
#             "locationTypeDisplay": "Brewpub",
#             "longitude": -105.2804358,
#             "name": "(Closed) Boulder Beer on Walnut",
#             "openToPublic": "N",
#             "postalCode": "80302",
#             "region": "Colorado",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "1123 Walnut St",
#             "updateDate": "2019-02-27 19:46:18",
#             "yearOpened": "2017"
#         },
#         {
#             "brewery": {
#                 "createDate": "2018-08-14 22:59:03",
#                 "description": "Torr Vacum Distillery and  Brewery is located at 490 Mill St. in Downtown Reno, the building was originally constructed in 1940 as the Ring-Lee Grocery Store.\r\n\r\nFor nearly two years we remodeled making sure to maintain as much of the original building feel as possible. Tables and chairs were made from materials we uncovered during demolition. The taproom showcases the original truss ceilings, brick masonry and maple hardwood floors and blends it with a modern design. Our outdoor patio is dog friendly for well behaved, leashed good boys and good girls. A perfect place to sip a cocktail made with 10 Torr Spirits or 10 Torr Precision Crafted Beer.",
#                 "id": "9JkdJu",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/9JkdJu/upload_QnSOKZ-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/9JkdJu/upload_QnSOKZ-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/9JkdJu/upload_QnSOKZ-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/9JkdJu/upload_QnSOKZ-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/9JkdJu/upload_QnSOKZ-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "10 Torr Distilling and Brewing",
#                 "nameShortDisplay": "10 Torr Distilling",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-08 18:59:55",
#                 "website": "https://10torr.com/"
#             },
#             "breweryId": "9JkdJu",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2018-08-15 19:13:34",
#             "hoursOfOperationExplicit": {
#                 "fri": [
#                     {
#                         "endTime": "10:00pm",
#                         "startTime": "1:00pm"
#                     }
#                 ],
#                 "mon": [
#                     {
#                         "endTime": "9:00pm",
#                         "startTime": "3:00pm"
#                     }
#                 ],
#                 "sat": [
#                     {
#                         "endTime": "10:00pm",
#                         "startTime": "12:00pm"
#                     }
#                 ],
#                 "sun": [
#                     {
#                         "endTime": "6:00pm",
#                         "startTime": "12:00pm"
#                     }
#                 ],
#                 "thu": [
#                     {
#                         "endTime": "10:00pm",
#                         "startTime": "1:00pm"
#                     }
#                 ],
#                 "tue": [
#                     {
#                         "endTime": "9:00pm",
#                         "startTime": "3:00pm"
#                     }
#                 ],
#                 "wed": [
#                     {
#                         "endTime": "10:00pm",
#                         "startTime": "1:00pm"
#                     }
#                 ]
#             },
#             "hoursOfOperationExplicitString": "wed-1:00pm-10:00pm,thu-1:00pm-10:00pm,fri-1:00pm-10:00pm,sat-12:00pm-10:00pm,sun-12:00pm-6:00pm,mon-3:00pm-9:00pm,tue-3:00pm-9:00pm",
#             "id": "NpnmAJ",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 39.5255325,
#             "locality": "Reno",
#             "locationType": "micro",
#             "locationTypeDisplay": "Micro Brewery",
#             "longitude": -119.8058148,
#             "name": "10 Torr Distilling and Brewing",
#             "openToPublic": "Y",
#             "phone": "(775) 499-5276",
#             "postalCode": "89502",
#             "region": "Nevada",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "490 Mill St",
#             "updateDate": "2018-08-15 19:13:34",
#             "website": "https://10torr.com/"
#         },
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "U90FDGLB6A",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2014-09-03 13:45:00",
#                 "established": "2014",
#                 "id": "9oltPu",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/9oltPu/upload_7fLGbX-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/9oltPu/upload_7fLGbX-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/9oltPu/upload_7fLGbX-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/9oltPu/upload_7fLGbX-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/9oltPu/upload_7fLGbX-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "127 Brewing",
#                 "nameShortDisplay": "127",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-08 22:41:26",
#                 "website": "https://www.facebook.com/127brewing"
#             },
#             "breweryId": "9oltPu",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2014-09-03 13:47:01",
#             "id": "4XTqCU",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 42.2860115,
#             "locality": "Jackson",
#             "locationType": "micro",
#             "locationTypeDisplay": "Micro Brewery",
#             "longitude": -84.4312613,
#             "name": "127 Brewing",
#             "openToPublic": "Y",
#             "phone": "(517) 258-1346",
#             "postalCode": "49201",
#             "region": "Michigan",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "3090 Shirley Drive",
#             "timezoneId": "America/New_York",
#             "updateDate": "2015-12-03 19:03:25",
#             "website": "https://www.facebook.com/127brewing",
#             "yearOpened": "2014"
#         },
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "40T3KHP9C8",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2018-05-06 13:49:29",
#                 "id": "GztlE6",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/GztlE6/upload_yvzuoW-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/GztlE6/upload_yvzuoW-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/GztlE6/upload_yvzuoW-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/GztlE6/upload_yvzuoW-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/GztlE6/upload_yvzuoW-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "14 Lakes Craft Brewing Co.",
#                 "nameShortDisplay": "14 Lakes Craft",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-09 00:29:10",
#                 "website": "https://www.facebook.com/14-Lakes-Brewery-Crosslake-Minnesota-1796465627048060/"
#             },
#             "breweryId": "GztlE6",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2018-05-09 17:58:29",
#             "hoursOfOperation": "Closed Monday, Tuesday, Wednesday",
#             "hoursOfOperationExplicit": {
#                 "fri": [
#                     {
#                         "endTime": "10:00pm",
#                         "startTime": "2:00pm"
#                     }
#                 ],
#                 "sat": [
#                     {
#                         "endTime": "10:00pm",
#                         "startTime": "2:00pm"
#                     }
#                 ],
#                 "sun": [
#                     {
#                         "endTime": "6:00pm",
#                         "startTime": "12:00pm"
#                     }
#                 ],
#                 "thu": [
#                     {
#                         "endTime": "8:00pm",
#                         "startTime": "4:00pm"
#                     }
#                 ]
#             },
#             "hoursOfOperationExplicitString": "thu-4:00pm-8:00pm,fri-2:00pm-10:00pm,sat-2:00pm-10:00pm,sun-12:00pm-6:00pm",
#             "hoursOfOperationNotes": "Closed Monday, Tuesday, Wednesday",
#             "id": "nII3c8",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 46.6870493,
#             "locality": "Crosslake",
#             "locationType": "micro",
#             "locationTypeDisplay": "Micro Brewery",
#             "longitude": -94.1120451,
#             "name": "14 Lakes Craft Brewing Co.",
#             "openToPublic": "Y",
#             "phone": "(218) 692-4129",
#             "postalCode": "56442",
#             "region": "Minnesota",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "36846 Co Hwy 66",
#             "timezoneId": "America/Chicago",
#             "updateDate": "2018-05-09 17:58:29"
#         },
#         {
#             "brewery": {
#                 "createDate": "2018-08-17 14:19:30",
#                 "id": "KUyiqG",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/KUyiqG/upload_mUjnem-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/KUyiqG/upload_mUjnem-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/KUyiqG/upload_mUjnem-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/KUyiqG/upload_mUjnem-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/KUyiqG/upload_mUjnem-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "1487 Brewery",
#                 "nameShortDisplay": "1487",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2019-01-10 16:58:12",
#                 "website": "https://www.1487brewery.com/"
#             },
#             "breweryId": "KUyiqG",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2018-09-12 19:58:42",
#             "id": "pZGs5j",
#             "inPlanning": "Y",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 39.9611755,
#             "locality": "Columbus",
#             "locationType": "micro",
#             "locationTypeDisplay": "Micro Brewery",
#             "longitude": -82.9987942,
#             "name": "1487 Brewery",
#             "openToPublic": "N",
#             "region": "Ohio",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "updateDate": "2018-09-12 19:58:42",
#             "website": "https://www.1487brewery.com/"
#         },
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "EK7TOJDRCA",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2012-01-03 02:41:56",
#                 "id": "sJqs5o",
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "Grand Lake Brewing Company",
#                 "nameShortDisplay": "Grand Lake",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-08 20:01:05",
#                 "website": "http://www.grandlakebrewing.com/"
#             },
#             "breweryId": "sJqs5o",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2012-01-03 02:41:56",
#             "hoursOfOperation": "Sunday-Thurs 11 am-10pm\r\n\r\nFriday 11 am-1130pm\r\n\r\nSat 11 am-1130pm",
#             "hoursOfOperationNotes": "Sunday-Thurs 11 am-10pm\r\n\r\nFriday 11 am-1130pm\r\n\r\nSat 11 am-1130pm",
#             "id": "OaZYgf",
#             "inPlanning": "N",
#             "isClosed": "Y",
#             "isPrimary": "Y",
#             "latitude": 40.4139425,
#             "locality": "Greeley",
#             "locationType": "micro",
#             "locationTypeDisplay": "Micro Brewery",
#             "longitude": -104.6937039,
#             "name": "16th Street Tavern",
#             "openToPublic": "N",
#             "phone": "9705843551",
#             "postalCode": "80631",
#             "region": "Colorado",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "915 16th St",
#             "timezoneId": "America/Denver",
#             "updateDate": "2016-01-13 16:41:41",
#             "website": "http://www.grandlakebrewing.com"
#         },
#         {
#             "brewery": {
#                 "createDate": "2014-09-13 02:03:54",
#                 "description": "Coming January 2015",
#                 "established": "2014",
#                 "id": "UrP3el",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/UrP3el/upload_z6px5X-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/UrP3el/upload_z6px5X-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/UrP3el/upload_z6px5X-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/UrP3el/upload_z6px5X-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/UrP3el/upload_z6px5X-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "4 Seasons Brewery",
#                 "nameShortDisplay": "4 Seasons",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-08 18:59:55",
#                 "website": "http://www.4seasonsbeer.com/"
#             },
#             "breweryId": "UrP3el",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2014-09-13 02:06:40",
#             "id": "eDYckD",
#             "inPlanning": "Y",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 43.0541724,
#             "locality": "Lapeer",
#             "locationType": "micro",
#             "locationTypeDisplay": "Micro Brewery",
#             "longitude": -83.3116716,
#             "name": "4 Seasons Brewery",
#             "openToPublic": "N",
#             "postalCode": "48846",
#             "region": "Michigan",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "303 W. Nepessing St.",
#             "timezoneId": "America/New_York",
#             "updateDate": "2015-12-03 15:55:11",
#             "website": "http://www.4seasonsbeer.com/"
#         },
#         {
#             "brewery": {
#                 "createDate": "2014-03-10 20:16:54",
#                 "description": "Currently in planning.  For info contact 40NorthBrewing@gmail.com",
#                 "established": "2011",
#                 "id": "jxEkl2",
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "40 North Brewing",
#                 "nameShortDisplay": "40 North",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-08 18:59:55",
#                 "website": "http://www.40NorthBrewing.com"
#             },
#             "breweryId": "jxEkl2",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2014-03-10 20:28:58",
#             "id": "AtnxIp",
#             "inPlanning": "Y",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 39.9991487,
#             "locality": "Boulder",
#             "locationType": "nano",
#             "locationTypeDisplay": "Nano Brewery",
#             "longitude": -105.2540857,
#             "name": "40 North Brewing",
#             "openToPublic": "N",
#             "postalCode": "80303",
#             "region": "Colorado",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "675 30th St",
#             "timezoneId": "America/Denver",
#             "updateDate": "2015-12-03 15:55:13",
#             "website": "http://www.40NorthBrewing.com"
#         },
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "SFB85R6OCK",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2015-06-27 00:21:57",
#                 "id": "FcVHIq",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/FcVHIq/upload_v4ZwmW-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/FcVHIq/upload_v4ZwmW-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/FcVHIq/upload_v4ZwmW-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/FcVHIq/upload_v4ZwmW-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/FcVHIq/upload_v4ZwmW-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "405 Brewing Co.",
#                 "nameShortDisplay": "405",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-08 22:18:32",
#                 "website": "http://www.405brewing.com/"
#             },
#             "breweryId": "FcVHIq",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2015-06-27 00:26:59",
#             "id": "yLPdOG",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 35.2573645,
#             "locality": "Norman",
#             "locationType": "micro",
#             "locationTypeDisplay": "Micro Brewery",
#             "longitude": -97.4681971,
#             "name": "405 Brewing Co.",
#             "openToPublic": "Y",
#             "postalCode": "73069",
#             "region": "Oklahoma",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "1716 Topeka St",
#             "timezoneId": "America/Chicago",
#             "updateDate": "2015-12-03 15:55:15",
#             "website": "http://www.405brewing.com/"
#         },
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "STI7FRU3OD",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2018-01-24 17:17:58",
#                 "description": "Each of our beer recipes uses only the finest hops, wheat, barley, and other ingredients to combine for a fine tasting brew. The smoothness of each swallow is unsurpassed.",
#                 "id": "fFxVKX",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/fFxVKX/upload_AuoYQe-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/fFxVKX/upload_AuoYQe-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/fFxVKX/upload_AuoYQe-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/fFxVKX/upload_AuoYQe-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/fFxVKX/upload_AuoYQe-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "412 Brewery",
#                 "nameShortDisplay": "412",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-09 00:22:09",
#                 "website": "http://www.412brews.com/"
#             },
#             "breweryId": "fFxVKX",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2018-01-24 17:20:11",
#             "id": "gSO2fv",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 40.4728091,
#             "locality": "Mc Kees Rocks",
#             "locationType": "micro",
#             "locationTypeDisplay": "Micro Brewery",
#             "longitude": -80.0616894,
#             "name": "412 Brewery",
#             "openToPublic": "Y",
#             "postalCode": "15136",
#             "region": "Pennsylvania",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "706 Island Ave",
#             "timezoneId": "America/New_York",
#             "updateDate": "2018-01-24 17:20:11",
#             "website": "http://www.412brews.com/"
#         },
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "T8KIOH0RQA",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2016-10-12 02:18:39",
#                 "description": "Opened in September 2016 in Defiance, Ohio. Located on the Property of Eagle Rock Golf Club and Sweetwater Chophouse.  Specializing in Ale Fermentation and Grain to Glass Beer Production.",
#                 "established": "2016",
#                 "id": "qnqnz0",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/qnqnz0/upload_NB63KZ-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/qnqnz0/upload_NB63KZ-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/qnqnz0/upload_NB63KZ-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/qnqnz0/upload_NB63KZ-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/qnqnz0/upload_NB63KZ-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "Y",
#                 "name": "4KD Crick Brewery",
#                 "nameShortDisplay": "4KD Crick",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-09 00:03:11",
#                 "website": "http://www.4kdcrickbrewery.com"
#             },
#             "breweryId": "qnqnz0",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2016-10-12 02:25:05",
#             "hoursOfOperation": "Fall/Winter Hours\r\nThursday 4pm-10pm\r\nFriday 4pm-10pm\r\nSaturday 11am-10pm\r\nSunday 11am-8pm",
#             "hoursOfOperationNotes": "Fall/Winter Hours\r\nThursday 4pm-10pm\r\nFriday 4pm-10pm\r\nSaturday 11am-10pm\r\nSunday 11am-8pm",
#             "id": "lPAHJ7",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 41.2931092,
#             "locality": "Defiance",
#             "locationType": "nano",
#             "locationTypeDisplay": "Nano Brewery",
#             "longitude": -84.3387212,
#             "name": "4kd Crick Brewery",
#             "openToPublic": "Y",
#             "phone": "419-576-5822",
#             "postalCode": "43512",
#             "region": "Ohio",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "211 Carpenter Rd",
#             "timezoneId": "America/New_York",
#             "updateDate": "2016-10-19 15:32:36",
#             "website": "www.4kdcrickbrewery.com",
#             "yearOpened": "2016"
#         },
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "P93Q4YW5BD",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2012-01-03 02:41:59",
#                 "description": "Karl Strauss Brewing Company has pioneered the San Diego beer scene since 1989 with innovative beer releases like Mosaic Session Ale, Big Barrel IIPA, and Wreck Alley Imperial Stout. The brewery has won 67 medals over the past five years and its Red Trolley Ale is one of the most award-winning beers in the world. The company is currently ranked #45 on the list of the country\u2019s top craft breweries with sole distribution in California. For more information visit www.karlstrauss.com or call the brewery at (858) 273-2739. Share it. Cheers.",
#                 "established": "1989",
#                 "id": "mtUjck",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/mtUjck/upload_nEAVib-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/mtUjck/upload_nEAVib-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/mtUjck/upload_nEAVib-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/mtUjck/upload_nEAVib-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/mtUjck/upload_nEAVib-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "Y",
#                 "name": "Karl Strauss Brewing Company",
#                 "nameShortDisplay": "Karl Strauss",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-08 19:29:29",
#                 "website": "http://www.karlstrauss.com/"
#             },
#             "breweryId": "mtUjck",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2014-07-25 22:39:57",
#             "hoursOfOperation": "Monday - Thursday - bar open til 11:00pm\r\nFriday-Saturday - bar open til midnight",
#             "hoursOfOperationExplicit": {
#                 "fri": [
#                     {
#                         "endTime": "11:00pm",
#                         "startTime": "11:00am"
#                     }
#                 ],
#                 "mon": [
#                     {
#                         "endTime": "10:00pm",
#                         "startTime": "11:00am"
#                     }
#                 ],
#                 "sat": [
#                     {
#                         "endTime": "11:00pm",
#                         "startTime": "11:00am"
#                     }
#                 ],
#                 "sun": [
#                     {
#                         "endTime": "10:00pm",
#                         "startTime": "11:00am"
#                     }
#                 ],
#                 "thu": [
#                     {
#                         "endTime": "10:00pm",
#                         "startTime": "11:00am"
#                     }
#                 ],
#                 "tue": [
#                     {
#                         "endTime": "10:00pm",
#                         "startTime": "11:00am"
#                     }
#                 ],
#                 "wed": [
#                     {
#                         "endTime": "10:00pm",
#                         "startTime": "11:00am"
#                     }
#                 ]
#             },
#             "hoursOfOperationExplicitString": "sun-11:00am-10:00pm,mon-11:00am-10:00pm,tue-11:00am-10:00pm,wed-11:00am-10:00pm,thu-11:00am-10:00pm,fri-11:00am-11:00pm,sat-11:00am-11:00pm",
#             "hoursOfOperationNotes": "Monday - Thursday - bar open til 11:00pm\r\nFriday-Saturday - bar open til midnight",
#             "id": "LVFUZJ",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "N",
#             "latitude": 33.021301,
#             "locality": "San Diego",
#             "locationType": "brewpub",
#             "locationTypeDisplay": "Brewpub",
#             "longitude": -117.113249,
#             "name": "4S Ranch",
#             "openToPublic": "Y",
#             "phone": "858-376-2739",
#             "postalCode": "92127",
#             "region": "California",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "10448 Reserve Drive",
#             "timezoneId": "America/Los_Angeles",
#             "updateDate": "2014-07-26 00:28:41",
#             "website": "http://www.karlstrauss.com/breweryrestaurants/4sranch.html"
#         },
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "4CG2R10YHA",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2018-08-17 15:32:15",
#                 "id": "grQtsy",
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "5770 Brewery",
#                 "nameShortDisplay": "5770",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-09 00:25:27"
#             },
#             "breweryId": "grQtsy",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2018-09-12 20:02:53",
#             "id": "RszgFA",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 39.1313951,
#             "locality": "Teutopolis",
#             "locationType": "production",
#             "locationTypeDisplay": "Production Facility",
#             "longitude": -88.4774922,
#             "name": "55/70 Brewery",
#             "openToPublic": "N",
#             "phone": "(618) 339-7841",
#             "postalCode": "62467",
#             "region": "Illinois",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "303 A West Main Street",
#             "updateDate": "2018-09-12 20:02:53",
#             "website": "www.5770brewery.com"
#         },
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "BXFVMOIJYU",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2018-05-19 20:47:40",
#                 "description": "6 Bears & a Goat Brewing Co., LLC (6B&G) is named after its founders (and the mascots of their respective military services).  The six Bears are 20-year retirees from the U.S. Coast Guard, and the Goat is a retiree from the U.S. Navy.  Collectively, the 6 Bears & a Goat have served their country for over 140 years.  While we are very serious about brewing beer, we want to have fun doing it, and our name is indicative of that\u2026it is also indicative of the good-natured rivalry between the Navy and our Nation\u2019s oldest continuous seagoing service, the United States Coast Guard.\r\n\r\n\u200b\r\n\r\nOver 10 years ago, these same seven owners started Harkcon, Inc., a Fredericksburg-based company that provides customized solutions to improve organizational performance for government agencies and private businesses.  When it came time for the 6 bears & the goat to expand their business line, the idea for a brewery was born!",
#                 "id": "zio7JW",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/zio7JW/upload_bl304Q-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/zio7JW/upload_bl304Q-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/zio7JW/upload_bl304Q-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/zio7JW/upload_bl304Q-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/zio7JW/upload_bl304Q-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "6 Bears and A Goat",
#                 "nameShortDisplay": "6 Bears",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-08 23:51:38",
#                 "website": "https://www.6bgbrewingco.com"
#             },
#             "breweryId": "zio7JW",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2018-05-19 20:47:43",
#             "hoursOfOperationExplicit": {
#                 "fri": [
#                     {
#                         "endTime": "11:00pm",
#                         "startTime": "12:00pm"
#                     }
#                 ],
#                 "sat": [
#                     {
#                         "endTime": "11:00pm",
#                         "startTime": "12:00pm"
#                     }
#                 ],
#                 "sun": [
#                     {
#                         "endTime": "7:00pm",
#                         "startTime": "12:00pm"
#                     }
#                 ],
#                 "thu": [
#                     {
#                         "endTime": "9:00pm",
#                         "startTime": "4:00pm"
#                     }
#                 ],
#                 "tue": [
#                     {
#                         "endTime": "9:00pm",
#                         "startTime": "4:00pm"
#                     }
#                 ],
#                 "wed": [
#                     {
#                         "endTime": "9:00pm",
#                         "startTime": "4:00pm"
#                     }
#                 ]
#             },
#             "hoursOfOperationExplicitString": "wed-4:00pm-9:00pm,thu-4:00pm-9:00pm,fri-12:00pm-11:00pm,sat-12:00pm-11:00pm,sun-12:00pm-7:00pm,tue-4:00pm-9:00pm",
#             "id": "4NSBRQ",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "N",
#             "latitude": 38.3625039,
#             "locality": "Fredericksburg",
#             "locationType": "brewpub",
#             "locationTypeDisplay": "Brewpub",
#             "longitude": -77.5142421,
#             "name": "6 Bears and A Goat",
#             "openToPublic": "Y",
#             "phone": "(540) 356-9056",
#             "postalCode": "22406",
#             "region": "Virginia",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "1140 International Parkway",
#             "timezoneId": "America/New_York",
#             "updateDate": "2018-08-20 14:40:01",
#             "website": "https://www.6bgbrewingco.com"
#         },
#         {
#             "brewery": {
#                 "createDate": "2018-08-17 15:32:20",
#                 "description": "6A Brewing Company began its adventure in January of 2017 when an old friend and brewer, Chris Meyer, who just finished a two-year stint as a lead brewer at DC Brau in the District of Columbia moved back to Cape Cod, Massachusetts and was hired as our Head Brewer.\r\nAfter receiving our license in December of 2017, Chris, with the help of his friend, Mark Jacobs (our Brewery Manager), began experimenting with different yeast strains, malts, and hops in the pursuit of our vision of building a local brewery that would support the local community, supply local pubs/restaurants of quality beers, and proudly represent Cape Cod as a new craft beer destination.\r\nChris, with an eye on more Traditional style beers, and Mark with an eye on New England style IPA\u2019s and Pale Ales began brewing an array of different brews on a 3 barrel brew house in an attempt to find the three beers that would help define our proud brewery.\r\n\r\nWe began distributing all our beers to our 4 pub partners, Flynn\u2019s Irish Pubs (3) and Father\u2019s Kitchen & Taphouse who both specialize in craft beers with a total of 216 craft beer tap lines between them in an attempt to gain immediate feedback from the local community.\r\nWe passed the test.\r\nOur goal at 6A Brewing Company remains to partner with craft beer pubs whose goal is to promote local businesses. Presently we don\u2019t have a taproom or public access to our brew house. All our beers can be found in the locations of our Pub Partners.",
#                 "established": "2017",
#                 "id": "XobKLH",
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "6A Brewing Company",
#                 "nameShortDisplay": "6A",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-08 18:59:55",
#                 "website": "https://6abrewing.com/"
#             },
#             "breweryId": "XobKLH",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2018-09-12 20:06:10",
#             "id": "4CiUOb",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 41.7589615,
#             "locality": "Sandwitch",
#             "locationType": "micro",
#             "locationTypeDisplay": "Micro Brewery",
#             "longitude": -70.4939317,
#             "name": "6A Brewing Company",
#             "openToPublic": "N",
#             "region": "Maine",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "updateDate": "2018-09-12 20:06:10",
#             "website": "https://6abrewing.com/"
#         },
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "8TMGDOSBH6",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2017-01-22 22:05:14",
#                 "description": "We are a craft brewery that seeks to produce great beers. We make recipes with all kinds of malts, grains, hops sugars and other flavorings. Our goal is make great beer as interesting as the people who drink it . We focus on delivering a product that reflects the tastes of the community that we serve. Something for everybody.",
#                 "established": "2016",
#                 "id": "H3EyoS",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/H3EyoS/upload_CGXFBT-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/H3EyoS/upload_CGXFBT-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/H3EyoS/upload_CGXFBT-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/H3EyoS/upload_CGXFBT-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/H3EyoS/upload_CGXFBT-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "Y",
#                 "mailingListUrl": "https://7milebrew.us15.list-manage.com/subscribe/post?u=e7586bc28622639093e117f7c&id=57f2aaeb71",
#                 "name": "7 Mile Brewery",
#                 "nameShortDisplay": "7 Mile",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-08 23:29:48",
#                 "website": "http://www.7milebrew.com/"
#             },
#             "breweryId": "H3EyoS",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2017-01-22 22:08:14",
#             "hoursOfOperation": "Tue:  2:00pm - 8:00pm\r\nWed:  2:00pm - 8:00pm\r\nThu:  2:00pm - 8:00pm\r\nFri:  12:00pm - 10:00pm\r\nSat:  12:00pm - 10:00pm\r\nSun:  12:00pm - 6:00pm\r\n\r\nMon-Sat 12-10pm\r\nSun 12-6pm",
# ...
#                 "established": "1978",
#                 "id": "CJ7aEv",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/CJ7aEv/upload_Z20fd8-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/CJ7aEv/upload_Z20fd8-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/CJ7aEv/upload_Z20fd8-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/CJ7aEv/upload_Z20fd8-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/CJ7aEv/upload_Z20fd8-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "BJ's Restaurant and Brewery",
#                 "nameShortDisplay": "BJ's Restaurant",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-08 19:56:39",
#                 "website": "http://www.bjsrestaurants.com/"
#             },
#             "breweryId": "CJ7aEv",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2012-04-17 13:21:51",
#             "hoursOfOperation": "11am-12am Sunday-Thursday\n11am-1am Friday & Saturday",
#             "hoursOfOperationNotes": "11am-12am Sunday-Thursday\n11am-1am Friday & Saturday",
#             "id": "EHyEDE",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "N",
#             "latitude": 33.129773,
#             "locality": "Allen",
#             "locationType": "brewpub",
#             "locationTypeDisplay": "Brewpub",
#             "longitude": -96.654022,
#             "name": "Allen",
#             "openToPublic": "Y",
#             "phone": "972.678.4050",
#             "postalCode": "75002",
#             "region": "Texas",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "190 E. Stacy Road",
#             "updateDate": "2014-07-23 19:11:34"
#         },
#         {
#             "brewery": {
#                 "createDate": "2018-08-17 15:39:31",
#                 "description": "Buck Wild is a wildly-delicious 100% gluten-free craft beer brewed with malted gluten-free grains. It was born out of a passion to craft a 100% gluten-free beer that tastes exactly like a great beer should. From the beach to the trail to a night on the town, Buck Wild raises the bar for craft beer.",
#                 "id": "WUmJXQ",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/WUmJXQ/upload_hsXDyS-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/WUmJXQ/upload_hsXDyS-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/WUmJXQ/upload_hsXDyS-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/WUmJXQ/upload_hsXDyS-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/WUmJXQ/upload_hsXDyS-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "Alpenglow Beer Co",
#                 "nameShortDisplay": "Alpenglow Beer Co",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2019-01-10 21:13:14",
#                 "website": "https://buckwildbrew.com/"
#             },
#             "breweryId": "WUmJXQ",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2018-09-12 20:13:08",
#             "id": "IqA6hT",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 37.8857582,
#             "locality": "Lafayette",
#             "locationType": "micro",
#             "locationTypeDisplay": "Micro Brewery",
#             "longitude": -122.1180201,
#             "name": "Alpenglow Beer Company",
#             "openToPublic": "N",
#             "region": "California",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "updateDate": "2018-09-12 20:13:08"
#         },
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "QX0TSJFC69",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2017-04-13 13:15:30",
#                 "description": "Germans know and love their beer. After all, they have been perfecting the art and science of brewing it for over 500 years. No surprise, fine German imports continue to garner the world's highest awards, accolades and price tags. But ALTSTADT, unlike other premium imports, crafts it's truly exceptional, authentic German style beer here locally -- in the historic charm of Fredericksburg, Texas. \r\n\r\nOld Fredericksburg, established by German immigrants back in the mid 1800's, is where ALTSTADT gets its namesake from-- literally translates to \u201cold town\u201d -- where the heritage of old world German brewing first began. Today, ALTSTADT's German Brewmaster continues these time honored traditions of crafting smooth, supremely drinkable beers using only pure spring water and the highest quality imported 100% natural German hops, grain and yeast after meticulous preparation in a state-of-the-art facility second to none.",
#                 "established": "2016",
#                 "id": "9RctX5",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/9RctX5/upload_3Ovnsi-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/9RctX5/upload_3Ovnsi-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/9RctX5/upload_3Ovnsi-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/9RctX5/upload_3Ovnsi-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/9RctX5/upload_3Ovnsi-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "Y",
#                 "name": "Altstadt Brewery",
#                 "nameShortDisplay": "Altstadt",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-09 00:09:15",
#                 "website": "http://www.altstadtbeer.com"
#             },
#             "breweryId": "9RctX5",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2017-06-06 19:17:21",
#             "id": "vVMIwY",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 30.2252322,
#             "locality": "Frederikdsburg",
#             "locationType": "micro",
#             "locationTypeDisplay": "Micro Brewery",
#             "longitude": -98.7948595,
#             "name": "Altstadt Brewery",
#             "openToPublic": "N",
#             "phone": "(830) 304-2337",
#             "postalCode": "78624",
#             "region": "Texas",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "6120 US Hwy 290 East",
#             "timezoneId": "America/Chicago",
#             "updateDate": "2017-07-05 20:33:51",
#             "website": "www.altstadtbeer.com",
#             "yearOpened": "2016"
#         },
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "WQABFIP0JS",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2018-08-17 15:44:04",
#                 "id": "5MHauL",
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "American Brewers Inc",
#                 "nameShortDisplay": "American Brewers",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-12-18 19:08:44",
#                 "website": "http://www.americanbrewers.us/"
#             },
#             "breweryId": "5MHauL",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2018-09-12 20:17:49",
#             "id": "v9suqu",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "Y",
#             "latitude": 42.266251,
#             "locality": "Kalamazoo, MI 49001",
#             "locationType": "micro",
#             "locationTypeDisplay": "Micro Brewery",
#             "longitude": -85.5379261,
#             "name": "American Brewers Inc.",
#             "openToPublic": "Y",
#             "phone": "(269) 217-1920",
#             "postalCode": "49001",
#             "region": "Michigan",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "3408 Miller Rd #309, Kalamazoo, MI 49001",
#             "updateDate": "2018-09-12 20:17:49",
#             "website": "http://www.americanbrewers.us/"
#         },
#         {
#             "brewery": {
#                 "brewersAssociation": {
#                     "brewersAssocationId": "RWB3NIT12E",
#                     "isCertifiedCraftBrewer": "Y"
#                 },
#                 "createDate": "2012-02-13 00:30:15",
#                 "description": "Slumbrew is all about the synergy between craft products and every day consumption. Well conceived, locally-sourced, quality products should be an every day part of our lives \u2013 not a unique occurrence. This is the spirit of Slumbrew.\r\n\r\nSlumbrew is the research & development brand and concept of Somerville Brewing Company. Our mission is to brew unique, ingredient-driven beers that challenge common notions of what a beer should taste like. It is the result of nearly 15 years of beer travel and research by Caitlin Jewell and Jeff Leiter; and a decade of Jeff\u2019s homebrewing recipe formulation.\r\n\r\nWe produce a lot of small-run, pilot beers at the Slumbrew Beerlab, but only a small number make their way to commercial production. The Somerville Brewing Company contracts with regional breweries to make the best recipes for wide-spread commercial release, but each recipe is an evolving process of refinement. This model for beer production provides an opportunity to experiment with innovative local ingredients to produce craft beers that stand apart from typical formulations.",
#                 "established": "2011",
#                 "id": "gwDTjS",
#                 "images": {
#                     "icon": "https://brewerydb-images.s3.amazonaws.com/brewery/gwDTjS/upload_6jyi8Y-icon.png",
#                     "large": "https://brewerydb-images.s3.amazonaws.com/brewery/gwDTjS/upload_6jyi8Y-large.png",
#                     "medium": "https://brewerydb-images.s3.amazonaws.com/brewery/gwDTjS/upload_6jyi8Y-medium.png",
#                     "squareLarge": "https://brewerydb-images.s3.amazonaws.com/brewery/gwDTjS/upload_6jyi8Y-squareLarge.png",
#                     "squareMedium": "https://brewerydb-images.s3.amazonaws.com/brewery/gwDTjS/upload_6jyi8Y-squareMedium.png"
#                 },
#                 "isInBusiness": "Y",
#                 "isMassOwned": "N",
#                 "isOrganic": "N",
#                 "isVerified": "N",
#                 "name": "Somerville Brewing Company",
#                 "nameShortDisplay": "Somerville",
#                 "status": "verified",
#                 "statusDisplay": "Verified",
#                 "updateDate": "2018-11-08 21:12:26",
#                 "website": "http://www.slumbrew.com/"
#             },
#             "breweryId": "gwDTjS",
#             "country": {
#                 "createDate": "2012-01-03 02:41:33",
#                 "displayName": "United States",
#                 "isoCode": "US",
#                 "isoThree": "USA",
#                 "name": "UNITED STATES",
#                 "numberCode": 840
#             },
#             "countryIsoCode": "US",
#             "createDate": "2015-05-08 13:50:59",
#             "hoursOfOperationExplicit": {
#                 "fri": [
#                     {
#                         "endTime": "12:00am",
#                         "startTime": "11:00am"
#                     }
#                 ],
#                 "sat": [
#                     {
#                         "endTime": "12:00am",
#                         "startTime": "11:00am"
#                     }
#                 ],
#                 "sun": [
#                     {
#                         "endTime": "12:00am",
#                         "startTime": "11:00am"
#                     }
#                 ],
#                 "thu": [
#                     {
#                         "endTime": "12:00am",
#                         "startTime": "11:00am"
#                     }
#                 ],
#                 "tue": [
#                     {
#                         "endTime": "10:00pm",
#                         "startTime": "11:00am"
#                     }
#                 ],
#                 "wed": [
#                     {
#                         "endTime": "10:00am",
#                         "startTime": "11:00am"
#                     }
#                 ]
#             },
#             "hoursOfOperationExplicitString": "tue-11:00am-10:00pm,wed-11:00am-10:00am,thu-11:00am-12:00am,fri-11:00am-12:00am,sat-11:00am-12:00am,sun-11:00am-12:00am",
#             "id": "dgdVJz",
#             "inPlanning": "N",
#             "isClosed": "N",
#             "isPrimary": "N",
#             "latitude": 42.3941311,
#             "locality": "Somerville",
#             "locationType": "brewpub",
#             "locationTypeDisplay": "Brewpub",
#             "longitude": -71.079673,
#             "name": "American Fresh Beer Garden",
#             "openToPublic": "Y",
#             "phone": "1.800.428.1150",
#             "postalCode": "02145",
#             "region": "Massachusetts",
#             "status": "verified",
#             "statusDisplay": "Verified",
#             "streetAddress": "310 Canal St.",
#             "timezoneId": "America/New_York",
#             "updateDate": "2015-05-08 13:50:59"
#         }
#     ],
#     "numberOfPages": 192,
#     "status": "success",
#     "totalResults": 9576
# }
