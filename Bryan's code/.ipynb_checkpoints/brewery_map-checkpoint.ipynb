# %%
#import dependencies
import pandas as pd
import requests
import json
import gmaps
import time
from config import api_key
from config_new import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
#establish lists to hold variables
name = []
established = []
region = []
lat = []
lng = []

#loop to iterate through pages of brewery location data 
for page_num in range(1,193):
    
    #set sleep parameter for api call limit
    time.sleep(1)
    
    #query url
    url = "https://api.brewerydb.com/v2/locations/?key=" + api_key + "&countryIsoCode=US" + "&p=" + str(page_num)
                                                                                 
    print("Downloading", url)
    
    #request data from API                                                                            
    response=requests.get(url).json()

    #for loop to get data within eage page
    for brewery in response['data']:
        try:
            name.append(brewery['brewery']['name'])
        except:
            name.append(None)
        try:
            established.append(brewery['brewery']['established'])
        except:
            established.append(None)
        try:
            region.append(brewery['region'])
        except:
            region.append(None)
        try:
            lat.append(brewery['latitude'])
        except:
            lat.append(None)
        try:
            lng.append(brewery['longitude'])
        except:
            lng.append(None)
# Out:
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=1
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=2
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=3
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=4
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=5
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=6
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=7
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=8
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=9
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=10
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=11
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=12
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=13
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=14
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=15
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=16
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=17
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=18
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=19
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=20
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=21
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=22
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=23
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=24
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=25
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=26
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=27
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=28
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=29
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=30
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=31
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=32
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=33
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=34
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=35
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=36
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=37
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=38
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=39
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=40
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=41
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=42
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=43
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=44
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=45
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=46
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=47
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=48
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=49
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=50
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=51
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=52
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=53
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=54
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=55
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=56
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=57
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=58
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=59
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=60
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=61
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=62
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=63
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=64
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=65
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=66
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=67
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=68
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=69
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=70
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=71
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=72
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=73
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=74
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=75
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=76
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=77
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=78
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=79
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=80
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=81
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=82
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=83
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=84
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=85
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=86
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=87
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=88
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=89
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=90
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=91
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=92
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=93
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=94
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=95
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=96
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=97
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=98
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=99
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=100
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=101
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=102
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=103
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=104
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=105
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=106
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=107
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=108
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=109
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=110
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=111
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=112
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=113
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=114
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=115
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=116
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=117
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=118
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=119
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=120
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=121
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=122
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=123
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=124
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=125
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=126
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=127
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=128
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=129
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=130
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=131
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=132
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=133
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=134
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=135
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=136
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=137
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=138
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=139
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=140
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=141
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=142
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=143
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=144
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=145
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=146
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=147
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=148
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=149
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=150
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=151
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=152
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=153
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=154
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=155
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=156
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=157
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=158
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=159
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=160
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=161
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=162
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=163
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=164
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=165
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=166
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=167
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=168
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=169
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=170
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=171
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=172
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=173
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=174
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=175
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=176
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=177
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=178
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=179
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=180
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=181
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=182
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=183
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=184
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=185
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=186
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=187
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=188
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=189
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=190
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=191
# Downloading https://api.brewerydb.com/v2/locations/?key=313f5f7a6e376fea166da9deccf981b7&countryIsoCode=US&p=192

# %%
#create dataframe
brewery_df = pd.DataFrame({
                    "Name": name,
                    "Established Year": established,
                    "Region": region,
                    "Latitude": lat,
                    "Longitude": lng
                            })

new_df = brewery_df.sort_values("Region", ascending=False)
new_df.to_csv("new_brewery_data.csv")

# %%
#import cleaned csv file
csv = "/Users/bryanwood/Desktop/Project_1_Team_2/Bryan's code/us_brewery_list.csv"
clean_brewery_list = pd.read_csv(csv)
clean_brewery_list.head()
# Out:
#    Index                       Name  Year Opened    Region   Latitude  \
# 0      1      (512) Brewing Company         2008     Texas  30.223400
# 1      2     #FREEDOM Craft Brewery         2012  New York  41.264535
# 2      3  10 Barrel Brewing Company         2006     Idaho  43.617859
# 3      4  10 Barrel Brewing Company         2006    Oregon  44.056236
# 4      5  10 Barrel Brewing Company         2006    Oregon  44.089005
#
#     Longitude
# 0  -97.769736
# 1  -73.935607
# 2 -116.202689
# 3 -121.328605
# 4 -121.285385

# %%
locations = brewery_df[['Latitude', 'Longitude']]

brewery_layer = gmaps.symbol_layer(
    locations, fill_color='green', stroke_color='green', scale=2
)
fig = gmaps.figure()
fig.add_layer(brewery_layer)
fig
